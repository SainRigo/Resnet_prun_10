# %% [markdown]
# <a href="https://colab.research.google.com/github/SainRigo/Resnet_prun_10/blob/main/Untitled35_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import os


# we access the file where are store our images

print(os.listdir("/content/drive/MyDrive/plum_data/plum_data/"))
# Out:
# ['Good', 'Bad']

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, AveragePooling2D
from tensorflow.keras.layers import Concatenate , Flatten , Dense , Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications import DenseNet121 , VGG16
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import normalize
from tensorflow.keras.optimizers import Adam

# %%
defective_path_l = os.listdir('/content/drive/MyDrive/plum_data/plum_data/Bad/')
good_path_l = os.listdir('/content/drive/MyDrive/plum_data/plum_data/Good/')
len(defective_path_l)+ len(good_path_l)
# Out:
# 4507

# %%
Image_data = []        # in this list will be append all the images read
Labels_image = []      # in this list will be append the label (statu) in the same oder of each image


# here is the path to the infected images.
# we used a for loop with a step 2 to just read half of the images.

defective_path = "/content/drive/MyDrive/plum_data/plum_data/Bad/"
defective_path_l.sort()

for i in range(0, len(defective_path_l), 2):
    image_path = os.path.join(defective_path, defective_path_l[i])
    images_pil = cv2.imread(image_path)
    image_array = Image.fromarray(images_pil , 'RGB')                     # read of image as RGB
    resize_img = image_array.resize((224 , 224))                          # resizing of image
    Image_data.append(np.array(resize_img))
    Labels_image.append(1)                                                # label on the image


# here we look for the total number of images read and the number of labels in our list
len(Image_data), len(Labels_image)
# Out:
# (1877, 1877)

# %%
good_path = "/content/drive/MyDrive/plum_data/plum_data/Good/"
good_path_l.sort()

for j in range(0, len(good_path_l), 2):
    image_pathu = os.path.join(good_path, good_path_l[j])
    images_pilu = cv2.imread(image_pathu)
    image_arrayu = Image.fromarray(images_pilu, 'RGB')
    resize_imgu = image_arrayu.resize((224 , 224))
    Image_data.append(np.array(resize_imgu))
    Labels_image.append(0)

# we labeled the uninfected cells as 0


# here is the total images for the study
len(Image_data), len(Labels_image)
# Out:
# (2254, 2254)

# %%
cells = np.array(Image_data)
labels = np.array(Labels_image)

# %%
print('Shape of Cells : {} , shape of labels : {}'.format(cells.shape , labels.shape))
# Out:
# Shape of Cells : (2254, 224, 224, 3) , shape of labels : (2254,)

# %%
plt.figure(1 , figsize = (15 , 9))
n = 0
for i in range(8):
    n += 1
    r = np.random.randint(0 , cells.shape[0] , 1)
    plt.subplot(4 , 4 , n)
    plt.subplots_adjust(hspace = 0.56, wspace = 0.56)
    plt.imshow(cells[r[0]])
    plt.title('{} : {}'.format('defective fruit image' if labels[r[0]] == 1 else 'good fruit image' ,
                               labels[r[0]]) )
    plt.xticks([]) , plt.yticks([])

plt.show()

# %%
n = np.arange(cells.shape[0])
np.random.shuffle(n)
cells = cells[n]
labels = labels[n]

# %%
cells = cells.astype(np.float32)/255.00
labels = labels.astype(np.int32)

# %%
# we split the data into train, test and validation set

from sklearn.model_selection import train_test_split

train_x , X , train_y , Y = train_test_split(cells , labels, test_size = 0.3 , random_state = 111)

test_x, valid_x, test_y, valid_y = train_test_split(X,Y, test_size = 0.5, random_state= 111)

# %%
print('Proportion of the data:')
print("train set: X_train: {}, Y_train: {}".format(train_x.shape, train_y.shape))
print('%===============================================%')
print('Validation set: x_validation: {}, y_validation: {}'.format(valid_x.shape, valid_y.shape))
print('%===============================================%')
print("test shape: x_test: {}, y_test: {}".format(test_x.shape, test_y.shape))
# Out:
# Proportion of the data:
# train set: X_train: (1577, 224, 224, 3), Y_train: (1577,)
# %===============================================%
# Validation set: x_validation: (339, 224, 224, 3), y_validation: (339,)
# %===============================================%
# test shape: x_test: (338, 224, 224, 3), y_test: (338,)

# %%
plt.figure(1 , figsize = (15 ,5))
n = 0
for z , j in zip([train_y , valid_y,  test_y] , ['train labels','validation labels', 'test labels']):
    n += 1
    plt.subplot(1 , 3  , n)
    sns.countplot(x = z )
    plt.title(j)
plt.show()

# %%
# !pip install tensorflow_model_optimization
# Out:
# Collecting tensorflow_model_optimization
#   Downloading tensorflow_model_optimization-0.8.0-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: absl-py~=1.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow_model_optimization) (1.4.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow_model_optimization) (0.1.8)
# Requirement already satisfied: numpy~=1.23 in /usr/local/lib/python3.10/dist-packages (from tensorflow_model_optimization) (1.25.2)
# Requirement already satisfied: six~=1.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow_model_optimization) (1.16.0)
# Installing collected packages: tensorflow_model_optimization
# Successfully installed tensorflow_model_optimization-0.8.0

# %%
import tensorflow_model_optimization

# %%
from tensorflow.keras.losses import BinaryCrossentropy

# %%
import tensorflow_model_optimization
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from tensorflow_model_optimization.sparsity import keras as sparsity

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *


def resnet(input_shape, n_classes):

  def conv_bn_rl(x, f, k=1, s=1, p='same'):
    x = Conv2D(f, k, strides=s, padding=p)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x


  def identity_block(tensor, f):
    x = conv_bn_rl(tensor, f)
    x = conv_bn_rl(x, f, 3)
    x = Conv2D(4*f, 1)(x)
    x = BatchNormalization()(x)

    x = Add()([x, tensor])
    output = ReLU()(x)
    return output


  def conv_block(tensor, f, s):
    x = conv_bn_rl(tensor, f)
    x = conv_bn_rl(x, f, 3, s)
    x = Conv2D(4*f, 1)(x)
    x = BatchNormalization()(x)

    shortcut = Conv2D(4*f, 1, strides=s)(tensor)
    shortcut = BatchNormalization()(shortcut)

    x = Add()([x, shortcut])
    output = ReLU()(x)
    return output


  def resnet_block(x, f, r, s=2):
    x = conv_block(x, f, s)
    for _ in range(r-1):
      x = identity_block(x, f)
    return x


  input = Input(input_shape)

  x = conv_bn_rl(input, 64, 7, 2)
  x = MaxPool2D(3, strides=2, padding='same')(x)

  x = resnet_block(x, 64, 3, 1)
  x = resnet_block(x, 128, 4)
  x = resnet_block(x, 256, 6)
  x = resnet_block(x, 512, 3)

  x = GlobalAvgPool2D()(x)

  output = Dense(n_classes, activation='softmax')(x)

  model = Model(input, output)
  return model

n_classes = 2  # Replace with the actual number of classes in your classification problem

# Create the model instance using the resnet function
input_shape=(224, 224, 3)
model = resnet(input_shape, n_classes)

# Compile the model
model.compile(loss=BinaryCrossentropy(),
              optimizer=Adam(learning_rate=0.01),
              metrics=['accuracy'])

# Define the pruning parameters
pruning_params = {
    'pruning_schedule': sparsity.ConstantSparsity(target_sparsity=0.10, begin_step=0, end_step=-1, frequency=100)
}

# Apply pruning to the model
pruned_model = tf.keras.models.clone_model(model)
pruned_model = sparsity.prune_low_magnitude(pruned_model, **pruning_params)
pruned_model.build(input_shape)  # Rebuild the model after pruning

# Compile the pruned model
pruned_model.compile(loss=BinaryCrossentropy(),
                     optimizer=Adam(learning_rate=0.01),
                     metrics=['accuracy'])

pruned_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  prune_low_magnitude_conv2d  (None, 112, 112, 64)         18882     ['input_1[0][0]']
#   (PruneLowMagnitude)
#
#  prune_low_magnitude_batch_  (None, 112, 112, 64)         257       ['prune_low_magnitude_conv2d[0
#  normalization (PruneLowMag                                         ][0]']
#  nitude)
#
#  prune_low_magnitude_re_lu   (None, 112, 112, 64)         1         ['prune_low_magnitude_batch_no
#  (PruneLowMagnitude)                                                rmalization[0][0]']
#
#  prune_low_magnitude_max_po  (None, 56, 56, 64)           1         ['prune_low_magnitude_re_lu[0]
#  oling2d (PruneLowMagnitude                                         [0]']
#  )
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 64)           8258      ['prune_low_magnitude_max_pool
#  _1 (PruneLowMagnitude)                                             ing2d[0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 64)           257       ['prune_low_magnitude_conv2d_1
#  normalization_1 (PruneLowM                                         [0][0]']
#  agnitude)
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 64)           1         ['prune_low_magnitude_batch_no
#  1 (PruneLowMagnitude)                                              rmalization_1[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 64)           73794     ['prune_low_magnitude_re_lu_1[
#  _2 (PruneLowMagnitude)                                             0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 64)           257       ['prune_low_magnitude_conv2d_2
#  normalization_2 (PruneLowM                                         [0][0]']
#  agnitude)
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 64)           1         ['prune_low_magnitude_batch_no
#  2 (PruneLowMagnitude)                                              rmalization_2[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 256)          33026     ['prune_low_magnitude_re_lu_2[
#  _3 (PruneLowMagnitude)                                             0][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 256)          33026     ['prune_low_magnitude_max_pool
#  _4 (PruneLowMagnitude)                                             ing2d[0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 256)          1025      ['prune_low_magnitude_conv2d_3
#  normalization_3 (PruneLowM                                         [0][0]']
#  agnitude)
#
#  prune_low_magnitude_batch_  (None, 56, 56, 256)          1025      ['prune_low_magnitude_conv2d_4
#  normalization_4 (PruneLowM                                         [0][0]']
#  agnitude)
#
#  prune_low_magnitude_add (P  (None, 56, 56, 256)          1         ['prune_low_magnitude_batch_no
#  runeLowMagnitude)                                                  rmalization_3[0][0]',
#                                                                      'prune_low_magnitude_batch_no
#                                                                     rmalization_4[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 256)          1         ['prune_low_magnitude_add[0][0
#  3 (PruneLowMagnitude)                                              ]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 64)           32834     ['prune_low_magnitude_re_lu_3[
#  _5 (PruneLowMagnitude)                                             0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 64)           257       ['prune_low_magnitude_conv2d_5
#  normalization_5 (PruneLowM                                         [0][0]']
#  agnitude)
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 64)           1         ['prune_low_magnitude_batch_no
#  4 (PruneLowMagnitude)                                              rmalization_5[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 64)           73794     ['prune_low_magnitude_re_lu_4[
#  _6 (PruneLowMagnitude)                                             0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 64)           257       ['prune_low_magnitude_conv2d_6
#  normalization_6 (PruneLowM                                         [0][0]']
#  agnitude)
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 64)           1         ['prune_low_magnitude_batch_no
#  5 (PruneLowMagnitude)                                              rmalization_6[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 256)          33026     ['prune_low_magnitude_re_lu_5[
#  _7 (PruneLowMagnitude)                                             0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 256)          1025      ['prune_low_magnitude_conv2d_7
#  normalization_7 (PruneLowM                                         [0][0]']
#  agnitude)
#
#  prune_low_magnitude_add_1   (None, 56, 56, 256)          1         ['prune_low_magnitude_batch_no
#  (PruneLowMagnitude)                                                rmalization_7[0][0]',
#                                                                      'prune_low_magnitude_re_lu_3[
#                                                                     0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 256)          1         ['prune_low_magnitude_add_1[0]
#  6 (PruneLowMagnitude)                                              [0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 64)           32834     ['prune_low_magnitude_re_lu_6[
#  _8 (PruneLowMagnitude)                                             0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 64)           257       ['prune_low_magnitude_conv2d_8
#  normalization_8 (PruneLowM                                         [0][0]']
#  agnitude)
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 64)           1         ['prune_low_magnitude_batch_no
#  7 (PruneLowMagnitude)                                              rmalization_8[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 64)           73794     ['prune_low_magnitude_re_lu_7[
#  _9 (PruneLowMagnitude)                                             0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 64)           257       ['prune_low_magnitude_conv2d_9
#  normalization_9 (PruneLowM                                         [0][0]']
#  agnitude)
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 64)           1         ['prune_low_magnitude_batch_no
#  8 (PruneLowMagnitude)                                              rmalization_9[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 256)          33026     ['prune_low_magnitude_re_lu_8[
#  _10 (PruneLowMagnitude)                                            0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_10 (PruneLow                                         0[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_add_2   (None, 56, 56, 256)          1         ['prune_low_magnitude_batch_no
#  (PruneLowMagnitude)                                                rmalization_10[0][0]',
#                                                                      'prune_low_magnitude_re_lu_6[
#                                                                     0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 256)          1         ['prune_low_magnitude_add_2[0]
#  9 (PruneLowMagnitude)                                              [0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 128)          65666     ['prune_low_magnitude_re_lu_9[
#  _11 (PruneLowMagnitude)                                            0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 128)          513       ['prune_low_magnitude_conv2d_1
#  normalization_11 (PruneLow                                         1[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 128)          1         ['prune_low_magnitude_batch_no
#  10 (PruneLowMagnitude)                                             rmalization_11[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 128)          295042    ['prune_low_magnitude_re_lu_10
#  _12 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 128)          513       ['prune_low_magnitude_conv2d_1
#  normalization_12 (PruneLow                                         2[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 128)          1         ['prune_low_magnitude_batch_no
#  11 (PruneLowMagnitude)                                             rmalization_12[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 512)          131586    ['prune_low_magnitude_re_lu_11
#  _13 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 512)          262658    ['prune_low_magnitude_re_lu_9[
#  _14 (PruneLowMagnitude)                                            0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 512)          2049      ['prune_low_magnitude_conv2d_1
#  normalization_13 (PruneLow                                         3[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_batch_  (None, 28, 28, 512)          2049      ['prune_low_magnitude_conv2d_1
#  normalization_14 (PruneLow                                         4[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_add_3   (None, 28, 28, 512)          1         ['prune_low_magnitude_batch_no
#  (PruneLowMagnitude)                                                rmalization_13[0][0]',
#                                                                      'prune_low_magnitude_batch_no
#                                                                     rmalization_14[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 512)          1         ['prune_low_magnitude_add_3[0]
#  12 (PruneLowMagnitude)                                             [0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 128)          131202    ['prune_low_magnitude_re_lu_12
#  _15 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 128)          513       ['prune_low_magnitude_conv2d_1
#  normalization_15 (PruneLow                                         5[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 128)          1         ['prune_low_magnitude_batch_no
#  13 (PruneLowMagnitude)                                             rmalization_15[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 128)          295042    ['prune_low_magnitude_re_lu_13
#  _16 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 128)          513       ['prune_low_magnitude_conv2d_1
#  normalization_16 (PruneLow                                         6[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 128)          1         ['prune_low_magnitude_batch_no
#  14 (PruneLowMagnitude)                                             rmalization_16[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 512)          131586    ['prune_low_magnitude_re_lu_14
#  _17 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 512)          2049      ['prune_low_magnitude_conv2d_1
#  normalization_17 (PruneLow                                         7[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_add_4   (None, 28, 28, 512)          1         ['prune_low_magnitude_batch_no
#  (PruneLowMagnitude)                                                rmalization_17[0][0]',
#                                                                      'prune_low_magnitude_re_lu_12
#                                                                     [0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 512)          1         ['prune_low_magnitude_add_4[0]
#  15 (PruneLowMagnitude)                                             [0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 128)          131202    ['prune_low_magnitude_re_lu_15
#  _18 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 128)          513       ['prune_low_magnitude_conv2d_1
#  normalization_18 (PruneLow                                         8[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 128)          1         ['prune_low_magnitude_batch_no
#  16 (PruneLowMagnitude)                                             rmalization_18[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 128)          295042    ['prune_low_magnitude_re_lu_16
#  _19 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 128)          513       ['prune_low_magnitude_conv2d_1
#  normalization_19 (PruneLow                                         9[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 128)          1         ['prune_low_magnitude_batch_no
#  17 (PruneLowMagnitude)                                             rmalization_19[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 512)          131586    ['prune_low_magnitude_re_lu_17
#  _20 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 512)          2049      ['prune_low_magnitude_conv2d_2
#  normalization_20 (PruneLow                                         0[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_add_5   (None, 28, 28, 512)          1         ['prune_low_magnitude_batch_no
#  (PruneLowMagnitude)                                                rmalization_20[0][0]',
#                                                                      'prune_low_magnitude_re_lu_15
#                                                                     [0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 512)          1         ['prune_low_magnitude_add_5[0]
#  18 (PruneLowMagnitude)                                             [0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 128)          131202    ['prune_low_magnitude_re_lu_18
#  _21 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 128)          513       ['prune_low_magnitude_conv2d_2
#  normalization_21 (PruneLow                                         1[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 128)          1         ['prune_low_magnitude_batch_no
#  19 (PruneLowMagnitude)                                             rmalization_21[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 128)          295042    ['prune_low_magnitude_re_lu_19
#  _22 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 128)          513       ['prune_low_magnitude_conv2d_2
#  normalization_22 (PruneLow                                         2[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 128)          1         ['prune_low_magnitude_batch_no
#  20 (PruneLowMagnitude)                                             rmalization_22[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 512)          131586    ['prune_low_magnitude_re_lu_20
#  _23 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 512)          2049      ['prune_low_magnitude_conv2d_2
#  normalization_23 (PruneLow                                         3[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_add_6   (None, 28, 28, 512)          1         ['prune_low_magnitude_batch_no
#  (PruneLowMagnitude)                                                rmalization_23[0][0]',
#                                                                      'prune_low_magnitude_re_lu_18
#                                                                     [0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 512)          1         ['prune_low_magnitude_add_6[0]
#  21 (PruneLowMagnitude)                                             [0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 256)          262402    ['prune_low_magnitude_re_lu_21
#  _24 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 256)          1025      ['prune_low_magnitude_conv2d_2
#  normalization_24 (PruneLow                                         4[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 256)          1         ['prune_low_magnitude_batch_no
#  22 (PruneLowMagnitude)                                             rmalization_24[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          1179906   ['prune_low_magnitude_re_lu_22
#  _25 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_2
#  normalization_25 (PruneLow                                         5[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  23 (PruneLowMagnitude)                                             rmalization_25[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 1024)         525314    ['prune_low_magnitude_re_lu_23
#  _26 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 1024)         1049602   ['prune_low_magnitude_re_lu_21
#  _27 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 1024)         4097      ['prune_low_magnitude_conv2d_2
#  normalization_26 (PruneLow                                         6[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_batch_  (None, 14, 14, 1024)         4097      ['prune_low_magnitude_conv2d_2
#  normalization_27 (PruneLow                                         7[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_add_7   (None, 14, 14, 1024)         1         ['prune_low_magnitude_batch_no
#  (PruneLowMagnitude)                                                rmalization_26[0][0]',
#                                                                      'prune_low_magnitude_batch_no
#                                                                     rmalization_27[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 1024)         1         ['prune_low_magnitude_add_7[0]
#  24 (PruneLowMagnitude)                                             [0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          524546    ['prune_low_magnitude_re_lu_24
#  _28 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_2
#  normalization_28 (PruneLow                                         8[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  25 (PruneLowMagnitude)                                             rmalization_28[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          1179906   ['prune_low_magnitude_re_lu_25
#  _29 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_2
#  normalization_29 (PruneLow                                         9[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  26 (PruneLowMagnitude)                                             rmalization_29[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 1024)         525314    ['prune_low_magnitude_re_lu_26
#  _30 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 1024)         4097      ['prune_low_magnitude_conv2d_3
#  normalization_30 (PruneLow                                         0[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_add_8   (None, 14, 14, 1024)         1         ['prune_low_magnitude_batch_no
#  (PruneLowMagnitude)                                                rmalization_30[0][0]',
#                                                                      'prune_low_magnitude_re_lu_24
#                                                                     [0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 1024)         1         ['prune_low_magnitude_add_8[0]
#  27 (PruneLowMagnitude)                                             [0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          524546    ['prune_low_magnitude_re_lu_27
#  _31 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_3
#  normalization_31 (PruneLow                                         1[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  28 (PruneLowMagnitude)                                             rmalization_31[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          1179906   ['prune_low_magnitude_re_lu_28
#  _32 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_3
#  normalization_32 (PruneLow                                         2[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  29 (PruneLowMagnitude)                                             rmalization_32[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 1024)         525314    ['prune_low_magnitude_re_lu_29
#  _33 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 1024)         4097      ['prune_low_magnitude_conv2d_3
#  normalization_33 (PruneLow                                         3[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_add_9   (None, 14, 14, 1024)         1         ['prune_low_magnitude_batch_no
#  (PruneLowMagnitude)                                                rmalization_33[0][0]',
#                                                                      'prune_low_magnitude_re_lu_27
#                                                                     [0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 1024)         1         ['prune_low_magnitude_add_9[0]
#  30 (PruneLowMagnitude)                                             [0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          524546    ['prune_low_magnitude_re_lu_30
#  _34 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_3
#  normalization_34 (PruneLow                                         4[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  31 (PruneLowMagnitude)                                             rmalization_34[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          1179906   ['prune_low_magnitude_re_lu_31
#  _35 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_3
#  normalization_35 (PruneLow                                         5[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  32 (PruneLowMagnitude)                                             rmalization_35[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 1024)         525314    ['prune_low_magnitude_re_lu_32
#  _36 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 1024)         4097      ['prune_low_magnitude_conv2d_3
#  normalization_36 (PruneLow                                         6[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_add_10  (None, 14, 14, 1024)         1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_36[0][0]',
#                                                                      'prune_low_magnitude_re_lu_30
#                                                                     [0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 1024)         1         ['prune_low_magnitude_add_10[0
#  33 (PruneLowMagnitude)                                             ][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          524546    ['prune_low_magnitude_re_lu_33
#  _37 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_3
#  normalization_37 (PruneLow                                         7[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  34 (PruneLowMagnitude)                                             rmalization_37[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          1179906   ['prune_low_magnitude_re_lu_34
#  _38 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_3
#  normalization_38 (PruneLow                                         8[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  35 (PruneLowMagnitude)                                             rmalization_38[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 1024)         525314    ['prune_low_magnitude_re_lu_35
#  _39 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 1024)         4097      ['prune_low_magnitude_conv2d_3
#  normalization_39 (PruneLow                                         9[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_add_11  (None, 14, 14, 1024)         1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_39[0][0]',
#                                                                      'prune_low_magnitude_re_lu_33
#                                                                     [0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 1024)         1         ['prune_low_magnitude_add_11[0
#  36 (PruneLowMagnitude)                                             ][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          524546    ['prune_low_magnitude_re_lu_36
#  _40 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_4
#  normalization_40 (PruneLow                                         0[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  37 (PruneLowMagnitude)                                             rmalization_40[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          1179906   ['prune_low_magnitude_re_lu_37
#  _41 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_4
#  normalization_41 (PruneLow                                         1[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  38 (PruneLowMagnitude)                                             rmalization_41[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 1024)         525314    ['prune_low_magnitude_re_lu_38
#  _42 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 1024)         4097      ['prune_low_magnitude_conv2d_4
#  normalization_42 (PruneLow                                         2[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_add_12  (None, 14, 14, 1024)         1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_42[0][0]',
#                                                                      'prune_low_magnitude_re_lu_36
#                                                                     [0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 1024)         1         ['prune_low_magnitude_add_12[0
#  39 (PruneLowMagnitude)                                             ][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 512)          1049090   ['prune_low_magnitude_re_lu_39
#  _43 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 512)          2049      ['prune_low_magnitude_conv2d_4
#  normalization_43 (PruneLow                                         3[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 512)          1         ['prune_low_magnitude_batch_no
#  40 (PruneLowMagnitude)                                             rmalization_43[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 512)            4719106   ['prune_low_magnitude_re_lu_40
#  _44 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 512)            2049      ['prune_low_magnitude_conv2d_4
#  normalization_44 (PruneLow                                         4[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 512)            1         ['prune_low_magnitude_batch_no
#  41 (PruneLowMagnitude)                                             rmalization_44[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 2048)           2099202   ['prune_low_magnitude_re_lu_41
#  _45 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 2048)           4196354   ['prune_low_magnitude_re_lu_39
#  _46 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 2048)           8193      ['prune_low_magnitude_conv2d_4
#  normalization_45 (PruneLow                                         5[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_batch_  (None, 7, 7, 2048)           8193      ['prune_low_magnitude_conv2d_4
#  normalization_46 (PruneLow                                         6[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_add_13  (None, 7, 7, 2048)           1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_45[0][0]',
#                                                                      'prune_low_magnitude_batch_no
#                                                                     rmalization_46[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 2048)           1         ['prune_low_magnitude_add_13[0
#  42 (PruneLowMagnitude)                                             ][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 512)            2097666   ['prune_low_magnitude_re_lu_42
#  _47 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 512)            2049      ['prune_low_magnitude_conv2d_4
#  normalization_47 (PruneLow                                         7[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 512)            1         ['prune_low_magnitude_batch_no
#  43 (PruneLowMagnitude)                                             rmalization_47[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 512)            4719106   ['prune_low_magnitude_re_lu_43
#  _48 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 512)            2049      ['prune_low_magnitude_conv2d_4
#  normalization_48 (PruneLow                                         8[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 512)            1         ['prune_low_magnitude_batch_no
#  44 (PruneLowMagnitude)                                             rmalization_48[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 2048)           2099202   ['prune_low_magnitude_re_lu_44
#  _49 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 2048)           8193      ['prune_low_magnitude_conv2d_4
#  normalization_49 (PruneLow                                         9[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_add_14  (None, 7, 7, 2048)           1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_49[0][0]',
#                                                                      'prune_low_magnitude_re_lu_42
#                                                                     [0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 2048)           1         ['prune_low_magnitude_add_14[0
#  45 (PruneLowMagnitude)                                             ][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 512)            2097666   ['prune_low_magnitude_re_lu_45
#  _50 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 512)            2049      ['prune_low_magnitude_conv2d_5
#  normalization_50 (PruneLow                                         0[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 512)            1         ['prune_low_magnitude_batch_no
#  46 (PruneLowMagnitude)                                             rmalization_50[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 512)            4719106   ['prune_low_magnitude_re_lu_46
#  _51 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 512)            2049      ['prune_low_magnitude_conv2d_5
#  normalization_51 (PruneLow                                         1[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 512)            1         ['prune_low_magnitude_batch_no
#  47 (PruneLowMagnitude)                                             rmalization_51[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 2048)           2099202   ['prune_low_magnitude_re_lu_47
#  _52 (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 2048)           8193      ['prune_low_magnitude_conv2d_5
#  normalization_52 (PruneLow                                         2[0][0]']
#  Magnitude)
#
#  prune_low_magnitude_add_15  (None, 7, 7, 2048)           1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_52[0][0]',
#                                                                      'prune_low_magnitude_re_lu_45
#                                                                     [0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 2048)           1         ['prune_low_magnitude_add_15[0
#  48 (PruneLowMagnitude)                                             ][0]']
#
#  prune_low_magnitude_global  (None, 2048)                 1         ['prune_low_magnitude_re_lu_48
#  _average_pooling2d (PruneL                                         [0][0]']
#  owMagnitude)
#
#  prune_low_magnitude_dense   (None, 2)                    8196      ['prune_low_magnitude_global_a
#  (PruneLowMagnitude)                                                verage_pooling2d[0][0]']
#
# ==================================================================================================
# Total params: 47051046 (179.49 MB)
# Trainable params: 23538690 (89.79 MB)
# Non-trainable params: 23512356 (89.69 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy

# Learning rate is also a hyperparameter
model.compile(loss=BinaryCrossentropy(),
              optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

import tensorflow as tf

# %%
# Resize the training and validation data
train_x_resized = tf.image.resize(train_x, size=(224, 224))
valid_x_resized = tf.image.resize(valid_x, size=(224, 224))

# %%
import tensorflow as tf

# Convert labels to one-hot encoded format
train_y_one_hot = tf.keras.utils.to_categorical(train_y, num_classes=n_classes)
valid_y_one_hot = tf.keras.utils.to_categorical(valid_y, num_classes=n_classes)

# Compile the model
pruned_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define the UpdatePruningStep callback
callbacks = [
    sparsity.UpdatePruningStep()
]

# Train the model with the one-hot encoded labels and include the UpdatePruningStep callback
history = pruned_model.fit(
    train_x_resized,
    train_y_one_hot,
    epochs=16,
    validation_data=(valid_x_resized, valid_y_one_hot),
    callbacks=callbacks)
# Out:
# Epoch 1/16
# 50/50 [==============================] - 1550s 29s/step - loss: 0.6553 - accuracy: 0.8129 - val_loss: 0.3911 - val_accuracy: 0.8761
# Epoch 2/16
# 50/50 [==============================] - 1437s 29s/step - loss: 0.4056 - accuracy: 0.8453 - val_loss: 0.5844 - val_accuracy: 0.8761
# Epoch 3/16
# 50/50 [==============================] - 1440s 29s/step - loss: 0.3492 - accuracy: 0.8332 - val_loss: 0.7627 - val_accuracy: 0.8761
# Epoch 4/16
# 50/50 [==============================] - 1436s 29s/step - loss: 0.2706 - accuracy: 0.8725 - val_loss: 0.3654 - val_accuracy: 0.8761
# Epoch 5/16
# 50/50 [==============================] - 1433s 29s/step - loss: 0.2526 - accuracy: 0.8890 - val_loss: 0.4069 - val_accuracy: 0.8348
# Epoch 6/16
# 50/50 [==============================] - 1431s 29s/step - loss: 0.2975 - accuracy: 0.8732 - val_loss: 0.5535 - val_accuracy: 0.6785
# Epoch 7/16
# 50/50 [==============================] - 1423s 28s/step - loss: 0.2740 - accuracy: 0.8751 - val_loss: 0.6927 - val_accuracy: 0.6195
# Epoch 8/16
# 50/50 [==============================] - 1417s 28s/step - loss: 0.2521 - accuracy: 0.9017 - val_loss: 1.3536 - val_accuracy: 0.2419
# Epoch 9/16
# 50/50 [==============================] - 1427s 29s/step - loss: 0.2636 - accuracy: 0.8814 - val_loss: 0.3585 - val_accuracy: 0.8407
# Epoch 10/16
# 50/50 [==============================] - 1436s 29s/step - loss: 0.2348 - accuracy: 0.8941 - val_loss: 0.3230 - val_accuracy: 0.9056
# Epoch 11/16
# 50/50 [==============================] - 1428s 29s/step - loss: 0.1978 - accuracy: 0.9182 - val_loss: 0.3375 - val_accuracy: 0.8348
# Epoch 12/16
# 50/50 [==============================] - 1426s 29s/step - loss: 0.2007 - accuracy: 0.9106 - val_loss: 2.9263 - val_accuracy: 0.3894
# Epoch 13/16
# 50/50 [==============================] - 1431s 29s/step - loss: 0.2199 - accuracy: 0.9093 - val_loss: 0.4758 - val_accuracy: 0.8791
# Epoch 14/16
# 50/50 [==============================] - 1427s 29s/step - loss: 0.1880 - accuracy: 0.9138 - val_loss: 0.8332 - val_accuracy: 0.8761
# Epoch 15/16
# 50/50 [==============================] - 1441s 29s/step - loss: 0.2038 - accuracy: 0.9138 - val_loss: 0.2468 - val_accuracy: 0.9027
# Epoch 16/16
# 50/50 [==============================] - 1419s 28s/step - loss: 0.1523 - accuracy: 0.9385 - val_loss: 0.3085 - val_accuracy: 0.8614

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
loss =history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
acc = history.history['accuracy']
val_acc =history.history['val_accuracy']

# %%
plt.plot(epochs, acc, 'g', label = 'Training accuracy')
plt.plot(epochs, val_acc,'r', label = "Validation accuracy")
plt.plot(epochs, loss, 'b', label = 'Training loss')
plt.plot(epochs, val_loss, 'y', label = "Validation loss")
plt.title(" Training and validation metric evolution")
plt.xlabel("Epochs")
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()

# %%
import numpy as np

# Make predictions on validation data
predictions = pruned_model.predict(valid_x_resized)
predicted_classes = np.argmax(predictions, axis=1)

# Calculate metrics
num_correct = np.sum(predicted_classes == np.argmax(valid_y_one_hot, axis=1))
accuracy = num_correct / valid_y_one_hot.shape[0]

true_positives = np.sum(np.logical_and(predicted_classes == 1, np.argmax(valid_y_one_hot, axis=1) == 1))
false_positives = np.sum(np.logical_and(predicted_classes == 1, np.argmax(valid_y_one_hot, axis=1) != 1))
false_negatives = np.sum(np.logical_and(predicted_classes != 1, np.argmax(valid_y_one_hot, axis=1) == 1))

precision = true_positives / (true_positives + false_positives)
recall = true_positives / (true_positives + false_negatives)
f1 = 2 * (precision * recall) / (precision + recall)

# Print results
print("Accuracy: {:.4f}".format(accuracy))
print("Precision: {:.4f}".format(precision))
print("Recall: {:.4f}".format(recall))
print("F1 Score: {:.4f}".format(f1))
# Out:
# 11/11 [==============================] - 72s 6s/step
# Accuracy: 0.8614
# Precision: 0.9433
# Recall: 0.8956
# F1 Score: 0.9188

# %%
model.save('Resnet.h1')
